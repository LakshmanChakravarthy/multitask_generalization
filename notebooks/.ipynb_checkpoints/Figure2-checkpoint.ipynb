# %% [markdown]
# # Figure 2
#
# The change in dimensionality of a region’s representations relative to its sources is determined by its connectivity dimensionality

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../src')
import utils
import plot_utils

import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# %%
projdir = '/home/ln275/f_mc1689_1/multitask_generalization/'
subProjDir = projdir + 'data/derivatives/RSM_ActFlow/'
helpfiles_dir = projdir + 'docs/experimentfiles/'
figoutdir = projdir + 'docs/figures/working/vertexwiseFC/'
fcdir = projdir + 'data/derivatives/FC_new/'

# %% [markdown]
# ## Figure 2A: Network definition brain plot

# %%
plot_utils.get_network_definition_brain_plot()
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.flat.32k_fs_LR.surf.gii was 0.043629 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.inflated_MSMAll.32k_fs_LR.surf.gii was 0.017266 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.027054 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.015834 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.flat.32k_fs_LR.surf.gii was 0.045097 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.inflated_MSMAll.32k_fs_LR.surf.gii was 0.017247 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.027127 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.015764 seconds.
#
#
# Info: Time to read /tmp/ImageParcellated.dlabel.nii was 0.041244 seconds.

# %% [markdown]
# ## Figure 2A: Plot FC gradients

# %%
gradients = np.load(fcdir + 'meansub_FCgrad_3PCs_0.8thr.npy')

# %%
X = gradients[:,1]
Y = gradients[:,0]
RAaxis = 'full'
xlabel = 'sensory-motor\n gradient\n' + r'(2$^{nd}$ PC of FC)'
ylabel = 'uni-transmodal\n gradient\n' + r'(1$^{st}$ PC of FC)'
outname = figoutdir + 'FCgrad1_vs_grad2.pdf'

plot_utils.customScatterPlot(X,Y,RAaxis,xlabel,ylabel,outname,legLoc='BR',xmin=None,xmax=None,ymin=None,ymax=None,
                            invert_xaxis=False,deg=1,xtickbins=4,ytickbins=4,
                            plotwidth=5.75,showstat=False,regplot=False)

plt.show()

# %%
# Label
networkNames = ['VIS1','VIS2','SMN-Fr','CON','DAN','LAN','FPN','AUD','DMN','PMULTI','VMM','ORA','SMN-Par']
networkpalette = np.array(['royalblue', 'slateblue', 'paleturquoise', 'darkorchid', 
                           'limegreen', 'lightseagreen', 'yellow', 'orchid', 'r', 
                           'peru', 'orange', 'olivedrab', 'teal'])

fig, ax = plot_utils.create_network_legend(networkNames, networkpalette)
plt.tight_layout()
plt.savefig(figoutdir + 'network_legend.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Figure 2B: Compression/Expansion

# %%
obs_dim = utils.get_obs_dimensionality()
meansub_obs_dim = np.mean(obs_dim,axis=0)

# %%
inputdata = meansub_obs_dim
file_out = 'meansub_obs_dim'
title = 'Representational Dimensionality'

plot_utils.get_brain_plot(inputdata,file_out,title,colormap='Purples')
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.flat.32k_fs_LR.surf.gii was 0.039786 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.inflated_MSMAll.32k_fs_LR.surf.gii was 0.0163 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.02471 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.014896 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.flat.32k_fs_LR.surf.gii was 0.040892 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.inflated_MSMAll.32k_fs_LR.surf.gii was 0.015887 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.024543 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.014807 seconds.
#
#
# Info: Time to read /tmp/ImageParcellated.dlabel.nii was 0.040709 seconds.

# %%
X = gradients[:,1]
Y = meansub_obs_dim

RAaxis = 'full'
xlabel = 'sensory-motor\ngradient'
ylabel = r'D$_{Rep}$'
outname = figoutdir + 'meansub_obsdim_vs_grad2.pdf'

plot_utils.customScatterPlot(X,Y,RAaxis,xlabel,ylabel,outname,legLoc='TL',ymin=None,ymax=None,xmin=None,xmax=None,
                            invert_xaxis=False,deg=2,xtickbins=3,ytickbins=4,
                            plotwidth=5,showstat=False)

plt.show()

# %%
dim_diff = utils.get_dim_diff()
meansub_dim_diff = np.mean(dim_diff,axis=0)

# %%
inputdata = meansub_dim_diff
file_out = 'meansub_dim_diff'
title = 'Compression/Expansion'

plot_utils.get_brain_plot(inputdata,file_out,title,ignore_zero=False)
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.flat.32k_fs_LR.surf.gii was 0.046001 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.inflated_MSMAll.32k_fs_LR.surf.gii was 0.018381 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.02847 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.017307 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.flat.32k_fs_LR.surf.gii was 0.044207 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.inflated_MSMAll.32k_fs_LR.surf.gii was 0.018323 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.028447 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.017194 seconds.
#
#
# Info: Time to read /tmp/ImageParcellated.dlabel.nii was 0.046669 seconds.

# %%
# Against sensory-motor gradient:

x = gradients[:,1]
y = meansub_dim_diff

coef,pval,aic_linear,aic_quad,delta_aic  = utils.get_quad_fit(x,y,n_perm=1000)
print('coef:',coef)
print('pval:',pval)
print('AIC comparison: linear: ',aic_linear, ' quad: ',aic_quad, ' linear-quad: ', delta_aic)
# Out:
# coef: [-0.07666034 -1.63626743 39.7889191 ]
# pval: [0.007 0.096 0.   ]
# AIC comparison: linear:  549.4757252826773  quad:  545.5352438997247  linear-quad:  3.940481382952612

# %%
X = gradients[:,1]
Y = meansub_dim_diff

RAaxis = 'full'
xlabel = 'sensory-motor\ngradient'
ylabel = r'ΔD$_{Rep}$'
outname = figoutdir + 'meansub_dimdiff_vs_grad2.pdf'

plot_utils.customScatterPlot(X,Y,RAaxis,xlabel,ylabel,outname,legLoc='TL',ymin=-1.5,ymax=2,xmin=None,xmax=None,
                            invert_xaxis=False,deg=2,xtickbins=3,ytickbins=4,
                            plotwidth=5,showstat=False)

plt.show()

# %%
ylabel=r'ΔD$_{Rep}$'
xlabel='sensory-motor\ngradient'

fig, ax, df = plot_utils.allNetsBoxPlot(
    Y1=dim_diff,  # shape: (n_subjects, 360)
    Y2=gradients,       # shape: (360, 2)
    networklist=[1,2,3,4,5,6,7,8,9,13],
    ylabel=ylabel,
    xlabel=xlabel,
    Y2_is_gradient=True,
    pc_idx=1,
    plotwidth=5
)

# plt.savefig(figoutdir + ylabel + '_vs_' + xlabel + '_AllNetworksBoxPlot.pdf', 
#                 transparent=True, bbox_inches='tight')
# plt.show()

# %% [markdown]
# ## Figure 2C: FC dimensionality

# %%
allsub_conn_dim = utils.get_FC_dimensionality()
meansub_conn_dim = np.mean(allsub_conn_dim,axis=0)

# %%
inputdata = meansub_conn_dim
file_out = 'meansub_conn_dim'
title = 'FC Dimensionality'

plot_utils.get_brain_plot(inputdata,file_out,title,colormap='Purples',ignore_zero=False)
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.flat.32k_fs_LR.surf.gii was 0.045549 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.inflated_MSMAll.32k_fs_LR.surf.gii was 0.018502 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.028502 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.01734 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.flat.32k_fs_LR.surf.gii was 0.044182 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.inflated_MSMAll.32k_fs_LR.surf.gii was 0.018237 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.02862 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.017178 seconds.
#
#
# Info: Time to read /tmp/ImageParcellated.dlabel.nii was 0.0472 seconds.

# %%
# Against sensory-motor gradient:

x = gradients[:,1]
y = meansub_conn_dim

coef,pval,aic_linear,aic_quad,delta_aic  = utils.get_quad_fit(x,y,n_perm=1000)
print('coef:',coef)
print('pval:',pval)
print('AIC comparison: linear: ',aic_linear, ' quad: ',aic_quad, ' linear-quad: ', delta_aic)
# Out:
# coef: [ 20.40596911  16.22477816 352.87415595]
# pval: [0.991 0.005 0.   ]
# AIC comparison: linear:  2199.150953617523  quad:  2208.908778592141  linear-quad:  -9.75782497461796

# %%
X = gradients[:,1]
Y = meansub_conn_dim
RAaxis = 'full'
xlabel = 'sensory-motor\ngradient'
ylabel = r'D$_{FC}$'
outname = figoutdir + 'meansub_FCdim_vs_grad2.pdf'

plot_utils.customScatterPlot(X,Y,RAaxis,xlabel,ylabel,outname,legLoc='TL',ymin=5,ymax=None,xmin=None,xmax=None,
                            invert_xaxis=False,deg=2,xtickbins=3,ytickbins=3,
                            plotwidth=5,showstat=False)

plt.show()

# %%
# fig, ax, df = plot_utils.allNetsBoxPlot(Y=allsub_conn_dim, ylabel=r'D$_{FC}$', gradient_loadings=gradients, pc_idx=1)

fig, ax, df = plot_utils.allNetsBoxPlot(
    Y1=allsub_conn_dim,  # shape: (n_subjects, 360)
    Y2=gradients,       # shape: (360, 2)
    networklist=[1,2,3,4,5,6,7,8,9,13],
    ylabel=r'D$_{FC}$',
    xlabel='Network position along gradient',
    Y2_is_gradient=True,
    pc_idx=1
)

# %% [markdown]
# ## Figure 2D: Rep. vs connectivity dimensionality

# %%
X = meansub_conn_dim
Y = meansub_dim_diff
RAaxis = 'full'
xlabel = r'D$_{FC}$'
ylabel = r'ΔD$_{Rep}$'
outname = figoutdir + 'meansub_dimdiff_vs_FCdim.pdf'

plot_utils.customScatterPlot(X,Y,RAaxis,xlabel,ylabel,outname,legLoc='TL',ymin=None,ymax=None,xmin=None,xmax=None,
                            invert_xaxis=False,deg=1,xtickbins=3,ytickbins=3,
                            plotwidth=5.25,showstat=True)

plt.show()

# %%
X = meansub_conn_dim
Y = meansub_dim_diff
RAaxis = 'onlysensory'
xlabel = r'D$_{FC}$'
ylabel = r'ΔD$_{Rep}$'
outname = figoutdir + 'meansub_dimdiff_vs_FCdim_sensory.pdf'

plot_utils.customScatterPlot(X,Y,RAaxis,xlabel,ylabel,outname,legLoc='TL',ymin=None,ymax=None,xmin=None,xmax=None,
                            invert_xaxis=False,deg=1,xtickbins=3,ytickbins=3,
                            plotwidth=5.25,showstat=True)

plt.show()

# %%
X = meansub_conn_dim
Y = meansub_dim_diff
RAaxis = 'onlyassociation'
xlabel = r'D$_{FC}$'
ylabel = r'ΔD$_{Rep}$'
outname = figoutdir + 'meansub_dimdiff_vs_FCdim_association.pdf'

fig,r,p = plot_utils.customScatterPlot(X,Y,RAaxis,xlabel,ylabel,outname,legLoc='TL',ymin=None,ymax=None,xmin=None,xmax=None,
                            invert_xaxis=False,deg=1,xtickbins=3,ytickbins=3,
                            plotwidth=5.25,showstat=True)

plt.show()
print(r,p)
# Out:
# 0.44 2.0011652893194712e-14

# %%
X = meansub_conn_dim
Y = meansub_dim_diff
RAaxis = 'onlymotor'
xlabel = r'D$_{FC}$'
ylabel = r'ΔD$_{Rep}$'
outname = figoutdir + 'meansub_dimdiff_vs_FCdim_motor.pdf'

fig,r,p = plot_utils.customScatterPlot(X,Y,RAaxis,xlabel,ylabel,outname,legLoc='TL',ymin=None,ymax=None,xmin=None,xmax=None,
                            invert_xaxis=False,deg=1,xtickbins=3,ytickbins=3,
                            plotwidth=5.25,showstat=True)

plt.show()
print(r,p)
# Out:
# 0.69 0.0011650947022178513

# %%
x = meansub_conn_dim
y = meansub_dim_diff

obs_r, pval = utils.get_brainsmash_correlation(x,y,n_perm=1000)
print('obs_r = ',obs_r, ', pval = ',pval)
# Out:
# obs_r =  0.43599208331624917 , pval =  0.0

# %%
fig, ax, df = plot_utils.allNetsBoxPlot(
    Y1=dim_diff,
    Y2=allsub_conn_dim,
    networklist=[1,2,3,4,5,6,7,8,9,13],
    ylabel=r'ΔD$_{Rep}$',
    xlabel=r'D$_{FC}$',
    Y2_is_gradient=False
)

# %% [markdown]
# ### Regressing out confounds and recomputing correlation

# %% [markdown]
# #### Counfounds:
#  * Target Size
#  * SNR (RSM diagonal mean)
#  * Intervertex distance (average across vertices in parcels)

# %%
region_size = utils.get_region_size()
meansub_RSM_SNR = utils.get_RSM_SNR()
intervertex_dist_LR_parcelmean = utils.get_parcelwise_intervertex_distance()
meansub_temporal_SD, meansub_spatial_SD = utils.get_activity_variance_and_spatial_homogeneity()

# %%
inputdata = region_size
file_out = 'delLater_region_size'
title = 'region size'

plot_utils.get_brain_plot(inputdata,file_out,title, ignore_unvalid=True)
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.flat.32k_fs_LR.surf.gii was 0.039639 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.inflated_MSMAll.32k_fs_LR.surf.gii was 0.015986 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.024646 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.01485 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.flat.32k_fs_LR.surf.gii was 0.040618 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.inflated_MSMAll.32k_fs_LR.surf.gii was 0.015792 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.024382 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.014691 seconds.
#
#
# Info: Time to read /tmp/ImageParcellated.dlabel.nii was 0.041733 seconds.

# %%
X = region_size
Y = meansub_dim_diff
RAaxis = 'full'
xlabel = 'region size'
ylabel = r'ΔD$_{Rep}$'
outname = figoutdir + 'meansub_dimdiff_vs_region_size.pdf'

plot_utils.customScatterPlot(X,Y,RAaxis,xlabel,ylabel,outname,legLoc='BR',ymin=None,ymax=None,xmin=None,xmax=None,
                            invert_xaxis=False,deg=1,xtickbins=3,ytickbins=3,
                            plotwidth=5.25,showstat=True)
plt.show()

# %%
inputdata = meansub_RSM_SNR
file_out = 'delLater_meansub_RSM_SNR'
title = 'signal to noise ratio'

plot_utils.get_brain_plot(inputdata,file_out,title, ignore_unvalid=True)
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.flat.32k_fs_LR.surf.gii was 0.039568 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.inflated_MSMAll.32k_fs_LR.surf.gii was 0.016065 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.023921 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.014647 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.flat.32k_fs_LR.surf.gii was 0.039498 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.inflated_MSMAll.32k_fs_LR.surf.gii was 0.015543 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.023503 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.014377 seconds.
#
#
# Info: Time to read /tmp/ImageParcellated.dlabel.nii was 0.04028 seconds.

# %%
X = meansub_RSM_SNR
Y = meansub_dim_diff
RAaxis = 'full'
xlabel = 'SNR'
ylabel = r'ΔD$_{Rep}$'
outname = figoutdir + 'meansub_dimdiff_vs_meansub_RSM_SNR.pdf'

plot_utils.customScatterPlot(X,Y,RAaxis,xlabel,ylabel,outname,legLoc='TL',ymin=None,ymax=None,xmin=None,xmax=None,
                            invert_xaxis=False,deg=1,xtickbins=3,ytickbins=3,
                            plotwidth=5.25,showstat=True)
plt.show()

# %%
inputdata = intervertex_dist_LR_parcelmean
file_out = 'delLater_intervertex_dist_LR_parcelmean'
title = 'inter-vertex distance'

plot_utils.get_brain_plot(inputdata,file_out,title, ignore_unvalid=True)
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.flat.32k_fs_LR.surf.gii was 0.039794 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.inflated_MSMAll.32k_fs_LR.surf.gii was 0.01605 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.025213 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.015084 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.flat.32k_fs_LR.surf.gii was 0.040662 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.inflated_MSMAll.32k_fs_LR.surf.gii was 0.015847 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.025102 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.014823 seconds.
#
#
# Info: Time to read /tmp/ImageParcellated.dlabel.nii was 0.042536 seconds.

# %%
X = intervertex_dist_LR_parcelmean
Y = meansub_dim_diff
RAaxis = 'full'
xlabel = 'inter-vertex distance'
ylabel = r'ΔD$_{Rep}$'
outname = figoutdir + 'meansub_dimdiff_vs_intervertexdist.pdf'

plot_utils.customScatterPlot(X,Y,RAaxis,xlabel,ylabel,outname,legLoc='TL',ymin=None,ymax=None,xmin=None,xmax=None,
                            invert_xaxis=False,deg=1,xtickbins=3,ytickbins=3,
                            plotwidth=5.25,showstat=True)
plt.show()

# %%
inputdata = meansub_temporal_SD
file_out = 'delLater_meansub_temporal_SD'
title = 'temporal SD'

plot_utils.get_brain_plot(inputdata,file_out,title, ignore_unvalid=True)
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.flat.32k_fs_LR.surf.gii was 0.039453 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.inflated_MSMAll.32k_fs_LR.surf.gii was 0.015993 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.024707 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.014988 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.flat.32k_fs_LR.surf.gii was 0.04073 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.inflated_MSMAll.32k_fs_LR.surf.gii was 0.015844 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.024491 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.01476 seconds.
#
#
# Info: Time to read /tmp/ImageParcellated.dlabel.nii was 0.04022 seconds.

# %%
X = meansub_temporal_SD
Y = meansub_dim_diff
RAaxis = 'full'
xlabel = 'temporal SD'
ylabel = r'ΔD$_{Rep}$'
outname = figoutdir + 'meansub_dimdiff_vs_temporalSD.pdf'

plot_utils.customScatterPlot(X,Y,RAaxis,xlabel,ylabel,outname,legLoc='TR',ymin=None,ymax=None,xmin=None,xmax=None,
                            invert_xaxis=False,deg=1,xtickbins=3,ytickbins=3,
                            plotwidth=5.25,showstat=True)
plt.show()

# %%
inputdata = meansub_spatial_SD
file_out = 'delLater_meansub_spatial_SD'
title = 'spatial SD'

plot_utils.get_brain_plot(inputdata,file_out,title, ignore_unvalid=True)
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.flat.32k_fs_LR.surf.gii was 0.039719 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.inflated_MSMAll.32k_fs_LR.surf.gii was 0.015447 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.023775 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.L.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.014498 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.flat.32k_fs_LR.surf.gii was 0.039656 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.inflated_MSMAll.32k_fs_LR.surf.gii was 0.015499 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.midthickness_MSMAll.32k_fs_LR.surf.gii was 0.024035 seconds.
#
#
# Info: Time to read /tmp/HumanCorticalParcellations/S1200.R.very_inflated_MSMAll.32k_fs_LR.surf.gii was 0.014366 seconds.
#
#
# Info: Time to read /tmp/ImageParcellated.dlabel.nii was 0.039622 seconds.

# %%
X = meansub_spatial_SD
Y = meansub_dim_diff
RAaxis = 'full'
xlabel = 'spatial SD'
ylabel = r'ΔD$_{Rep}$'
outname = figoutdir + 'meansub_dimdiff_vs_spatialSD.pdf'

plot_utils.customScatterPlot(X,Y,RAaxis,xlabel,ylabel,outname,legLoc='TR',ymin=None,ymax=None,xmin=None,xmax=None,
                            invert_xaxis=False,deg=1,xtickbins=3,ytickbins=3,
                            plotwidth=5.25,showstat=True)
plt.show()

# %%
# Checking any direct correlation of meansub_dim_diff and meansub_temporal_SD/meansub_spatial_SD

x = meansub_temporal_SD
y = meansub_dim_diff

obs_r, pval = utils.get_brainsmash_correlation(x,y,n_perm=1000)
print('obs_r = ',obs_r, ', pval = ',pval)
# Out:
# obs_r =  -0.3972243151696103 , pval =  0.001

# %%
x = meansub_spatial_SD
y = meansub_dim_diff

obs_r, pval = utils.get_brainsmash_correlation(x,y,n_perm=1000)
print('obs_r = ',obs_r, ', pval = ',pval)
# Out:
# obs_r =  -0.3104234483518606 , pval =  0.015

# %%
# Regressing out confounds from meansub_SVPR

X = np.hstack([region_size.reshape(-1,1),
               meansub_RSM_SNR.reshape(-1,1),
               intervertex_dist_LR_parcelmean.reshape(-1,1),
               meansub_temporal_SD.reshape(-1,1)])

# meansub_spatial_SD.reshape(-1,1), meansub_temporal_SD.reshape(-1,1)

y = meansub_conn_dim.reshape(-1,1)

coef,resid = utils.get_residual(X,y)
# Out:
# Variance Inflation Factors:
#   Regressor        VIF
# 0        X0   2.984290
# 1        X1   8.642562
# 2        X2  36.473798
# 3        X3  26.851003
#
# Multicollinearity warning: VIF > 5 indicates moderate, VIF > 10 indicates severe multicollinearity

# %%
x = np.squeeze(resid)
y = meansub_dim_diff

obs_r, pval = utils.get_brainsmash_correlation(x,y,n_perm=1000)
print('obs_r = ',obs_r, ', pval = ',pval)
# Out:
# obs_r =  0.2932307006483357 , pval =  0.001

# %%
X = np.squeeze(resid)
Y = meansub_dim_diff
RAaxis = 'full'
xlabel = r'D$_{FC}$ (residual)'
ylabel = r'ΔD$_{Rep}$'
outname = figoutdir + 'meansub_dimdiff_vs_FCdim_BScol_confounds_removed.pdf'

plot_utils.customScatterPlot(X,Y,RAaxis,xlabel,ylabel,outname,legLoc='TL',ymin=None,ymax=None,xmin=None,xmax=None,
                            invert_xaxis=False,deg=1,xtickbins=3,ytickbins=3,
                            plotwidth=5.25,showstat=True)
plt.show()

# %%
# Regressing out confounds from meansub_SVPR

X = np.hstack([region_size.reshape(-1,1),
               meansub_RSM_SNR.reshape(-1,1),
               intervertex_dist_LR_parcelmean.reshape(-1,1),
               meansub_spatial_SD.reshape(-1,1)])

# meansub_spatial_SD.reshape(-1,1), meansub_temporal_SD.reshape(-1,1)

y = meansub_conn_dim.reshape(-1,1)

coef,resid = utils.get_residual(X,y)
# Out:
# Variance Inflation Factors:
#   Regressor        VIF
# 0        X0   3.056393
# 1        X1   9.098084
# 2        X2  35.863230
# 3        X3  23.597306
#
# Multicollinearity warning: VIF > 5 indicates moderate, VIF > 10 indicates severe multicollinearity

# %%
x = np.squeeze(resid)
y = meansub_dim_diff

obs_r, pval = utils.get_brainsmash_correlation(x,y,n_perm=1000)
print('obs_r = ',obs_r, ', pval = ',pval)
# Out:
# obs_r =  0.32070536587145265 , pval =  0.0

# %%
X = np.squeeze(resid)
Y = meansub_dim_diff
RAaxis = 'full'
xlabel = r'D$_{FC}$ (residual)'
ylabel = r'ΔD$_{Rep}$'
outname = figoutdir + 'meansub_dimdiff_vs_FCdim_BScol_spatialSD_removed.pdf'

plot_utils.customScatterPlot(X,Y,RAaxis,xlabel,ylabel,outname,legLoc='TL',ymin=None,ymax=None,xmin=None,xmax=None,
                            invert_xaxis=False,deg=1,xtickbins=3,ytickbins=3,
                            plotwidth=5.25,showstat=True)
plt.show()
